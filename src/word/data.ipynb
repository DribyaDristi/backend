# %%
import pandas as pd

df1 = pd.read_parquet('C:\\Users\\Acer\\Desktop\\DribhyaDrishti\\src\\asl-signs\\train_landmark_files\\26734\\1000035562.parquet')
df2 = pd.read_parquet('C:\\Users\\Acer\\Desktop\\DribhyaDrishti\\src\\asl-signs\\train_landmark_files\\28656\\1000106739.parquet')

df3 = pd.read_csv('train.csv')
# df3 contains one column named sign, extract only that column with removing duplicates and in ascending order
df3 = df3['sign'].drop_duplicates().sort_values().reset_index(drop=True)
# save the extracted column to a new csv file
df3.to_csv('signs.csv', index=False)

print(df1.shape, df2.shape, df3.shape)
print(df3)
# Out:
# (12489, 7) (5973, 7) (250,)
# 0             TV
# 1          after
# 2       airplane
# 3            all
# 4      alligator
#          ...
# 245    yesterday
# 246     yourself
# 247        yucky
# 248        zebra
# 249       zipper
# Name: sign, Length: 250, dtype: object
